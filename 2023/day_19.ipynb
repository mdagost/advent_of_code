# %% [markdown]
# ## Part 1

# %%
import re

# %%
TEST_INFILE = "inputs/day_19_test_1.txt"
INFILE = "inputs/day_19_1.txt"

with open(TEST_INFILE) as infile:
#with open(INFILE) as infile:
    input = infile.read()
rules = input.split("\n\n")[0].split()
parts = input.split("\n\n")[1].split()

# %%
def process_rule(rule):
    rule_name  = rule.split("{")[0]
    rule_logic = rule.split("{")[1].rstrip("}")

    rules = rule_logic.split(",")
    parsed_rules = []
    for r in rules:
        rs = r.split(":")
        if len(rs) == 2:
            parsed_rules.append((rs[0], rs[1]))
        else:
            parsed_rules.append(("True", rs[0]))

    return rule_name, parsed_rules

# %%
rules = [process_rule(r) for r in rules]
rules = {rule_name: rule_logic for rule_name, rule_logic in rules}

# %%
# make each part a dict we can eval
parts = [re.sub("(x|m|a|s)", lambda m: f"'{m.group(0)}'", p.replace("=", ":")) for p in parts]

# %%
def process_part(part, debug=False):
    if debug: print(f"Examining part {part}")
    rule = "in"
    while True:
        if debug: print(f"Rule {rule}")
        sub_rules = rules[rule]
        for sub_rule in sub_rules:
            if debug: print(f"\tLooking at sub rule {sub_rule[0]} of {rule}")
            truth = eval(sub_rule[0], eval(part))
            if truth:
                if debug: print(f"\t Satisfied so => {sub_rule[1]}")
                rule = sub_rule[1]
                if rule == "A":
                    return ("A", eval("x+m+a+s", eval(part)))
                elif rule == "R":
                    return ("R", None)
                else:
                    break

# %%
results = [process_part(p) for p in parts]

# %%
sum(r[1] for r in results if r[0] == "A")
# Out:
# 19114

# %% [markdown]
# ## Part 2

# %%
from functools import reduce

# %%
TEST_INFILE = "inputs/day_19_test_1.txt"
INFILE = "inputs/day_19_1.txt"

#with open(TEST_INFILE) as infile:
with open(INFILE) as infile:
    input = infile.read()
rules = input.split("\n\n")[0].split()
parts = input.split("\n\n")[1].split()

# %%
class Range:
    def __init__(self, lo, hi, lo_included=False, hi_included=False):
        self.lo = lo
        self.hi = hi
        self.lo_included = lo_included
        self.hi_included = hi_included


    def __len__(self):
        hi = self.hi if self.hi_included else (self.hi - 1)
        lo = self.lo if self.lo_included else (self.lo + 1)
        return hi - lo + 1


    def __repr__(self):
        out = ""
        if self.lo_included:
            out += "["
        else:
            out += "("
        out += f"{self.lo}, {self.hi}"
        if self.hi_included:
            out += "]"
        else:
            out += ")"
        return out


    def __eq__(self, other):
        return self.lo == other.lo and self.hi == other.hi \
            and self.lo_included == other.lo_included \
            and self.hi_included == other.hi_included


    def __and__(self, other):
        if self.lo > other.hi or other.lo > self.hi:
            return None

        lo = max(self.lo, other.lo)
        hi = min(self.hi, other.hi)

        if lo == self.lo and lo != other.lo:
            lo_included = self.lo_included
        elif lo == other.lo and lo != self.lo:
            lo_included = other.lo_included
        else:
            lo_included = self.lo_included and other.lo_included

        if hi == self.hi and hi != other.hi:
            hi_included = self.hi_included
        elif hi == other.hi and hi != self.hi:
            hi_included = other.hi_included
        else:
            hi_included = self.hi_included and other.hi_included


        return Range(lo, hi, lo_included, hi_included)
    

assert str(Range(0, 1000)) == "(0, 1000)"
assert str(Range(0, 1000, lo_included=True)) == "[0, 1000)"
assert str(Range(0, 1000, hi_included=True)) == "(0, 1000]"
assert str(Range(-float("inf"), 1000)) == "(-inf, 1000)"

assert Range(-float("inf"), 10) & Range(5, float("inf")) == Range(5, 10)
assert Range(-float("inf"), 10) & Range(15, float("inf")) is None
assert Range(-float("inf"), 10) & Range(5, float(7)) == Range(5, 7)

assert Range(-float("inf"), 10) & Range(5, float("inf"), lo_included=True) == Range(5, 10, lo_included=True)
assert Range(-float("inf"), 10) & Range(5, float(7), lo_included=True, hi_included=True) == Range(5, 7, lo_included=True, hi_included=True)
assert Range(10, 15) & Range(10, 15, lo_included=True, hi_included=True) == Range(10, 15, lo_included=False, hi_included=False)

assert len(Range(1, 10)) == 8
assert len(Range(1, 10, lo_included=True)) == 9
assert len(Range(1, 10, hi_included=True)) == 9
assert len(Range(1, 10, lo_included=True, hi_included=True)) == 10

# %%
class RangeSet:
    def __init__(self, ranges=None):
        if not ranges:
            ranges = {
                "x": Range(-float("inf"), float("inf")),
                "m": Range(-float("inf"), float("inf")),
                "a": Range(-float("inf"), float("inf")),
                "s": Range(-float("inf"), float("inf"))
            }
            self.ranges = ranges
        else:
            self.ranges = ranges


    def __repr__(self):
        return f"RangeSet(ranges={self.ranges})"
    

    def __and__(self, other):
        out = RangeSet()
        for var in self.ranges.keys():
            out.ranges[var] = self.ranges[var] & other.ranges[var]
        return out
    
    def __len__(self):
        return len(self.ranges["x"]) * len(self.ranges["m"]) * len(self.ranges["a"]) * len(self.ranges["s"])

# %%
def process_rule(rule, debug=False):
    rule_name  = rule.split("{")[0]
    rule_logic = rule.split("{")[1].rstrip("}")

    rules = rule_logic.split(",")
    
    output = []
    prev = RangeSet()
    for rule in rules:
        if debug: print(f"Looking at rule {rule}")

        subrule = rule.split(":")
        subrule_yes = RangeSet()
        subrule_no  = RangeSet()
        
        # full rule, not the last default case
        if len(subrule) == 2:
            var, op, pred = re.split("(>|<)", subrule[0])
            if op == "<":
                rule_range     = Range(-float("inf"), int(pred))
                not_rule_range = Range(int(pred), float("inf"), lo_included=True)
            elif op == ">":
                rule_range     = Range(int(pred), float("inf"))
                not_rule_range = Range(-float("inf"), int(pred), hi_included=True)
            else:
                raise ValueError(f"Unknown operator {op} in rule {subrule[0]}!!")

            subrule_yes.ranges[var] = subrule_yes.ranges[var] & rule_range
            subrule_no.ranges[var]  = subrule_no.ranges[var]  & not_rule_range

            yes = prev & subrule_yes
            no  = prev & subrule_no

            output.append((subrule[1], yes))
            prev = no
        else:
            output.append((subrule[0], no))

    return rule_name, output

# %%
edges = {}
for r in rules:
    rule_name, output_edges = process_rule(r)
    edges[rule_name] = output_edges

# %%
def path_to_end(from_node, edges, path_to_node):
    paths = []
    for neighbor_node, edge_rangeset in edges[from_node]:
        if neighbor_node == "R":
            continue
        elif neighbor_node == "A":
            paths.append(path_to_node + [(neighbor_node, edge_rangeset)])
        else:
            path = path_to_end(neighbor_node, edges, path_to_node + [(neighbor_node, edge_rangeset)])
            if len(path):
                paths.extend(path)
    return paths

# %%
all_paths = path_to_end("in", edges, [])

# %%
parts_range = Range(1, 4000, lo_included=True, hi_included=True)
parts_rangeset = RangeSet(
    {
        "x": parts_range,
        "m": parts_range,
        "a": parts_range,
        "s": parts_range
    }
)

total = 0
for p in all_paths:
    for n in p:
        print(f"{n[0]}", end="")
        if n[0] != "A":
            print(" => ", end="")
    print("")
    path_rangeset = reduce(lambda x, y: x & y, [r[1] for r in p])
    parts = path_rangeset & parts_rangeset
    total += len(parts)
    print(f"\t{path_rangeset}")
    print(f"\t{parts}")
    print(f"\t{len(parts)}")
# Out:
# cd => qjl => zdd => nzs => svh => A
# 	RangeSet(ranges={'x': (-inf, 2228), 'm': (2131, inf), 'a': (2405, inf), 's': (911, 1624)})
# 	RangeSet(ranges={'x': [1, 2228), 'm': (2131, 4000], 'a': (2405, 4000], 's': (911, 1624)})
# 	4726832353320
# cd => qjl => zdd => nzs => svh => A
# 	RangeSet(ranges={'x': (-inf, 2228), 'm': (-inf, 2131], 'a': (2405, inf), 's': (1205, 1624)})
# 	RangeSet(ranges={'x': [1, 2228), 'm': [1, 2131], 'a': (2405, 4000], 's': (1205, 1624)})
# 	3164030315270
# cd => qjl => zdd => nzs => svh => sdj => A
# 	RangeSet(ranges={'x': (-inf, 2228), 'm': (1268, 2131], 'a': (2405, inf), 's': (911, 1205]})
# 	RangeSet(ranges={'x': [1, 2228), 'm': (1268, 2131], 'a': (2405, 4000], 's': (911, 1205]})
# 	901237035930
# cd => qjl => zdd => nzs => svh => sdj => A
# 	RangeSet(ranges={'x': (-inf, 2228), 'm': (-inf, 1268], 'a': (2405, 3341), 's': [1037, 1205]})
# 	RangeSet(ranges={'x': [1, 2228), 'm': [1, 1268], 'a': (2405, 3341), 's': [1037, 1205]})
# 	446208445540
# cd => qjl => zdd => nzs => drm => mx => A
# 	RangeSet(ranges={'x': [2228, 3299], 'm': (-inf, inf), 'a': (3290, inf), 's': (911, 1027]})
# 	RangeSet(ranges={'x': [2228, 3299], 'm': [1, 4000], 'a': (3290, 4000], 's': (911, 1027]})
# 	353159680000
# cd => qjl => zdd => nzs => qck => gx => A
# 	RangeSet(ranges={'x': (2827, inf), 'm': (-inf, inf), 'a': (2405, 2892], 's': (911, 1192)})
# 	RangeSet(ranges={'x': (2827, 4000], 'm': [1, 4000], 'a': (2405, 2892], 's': (911, 1192)})
# 	639801120000
# cd => qjl => zdd => nzs => qck => njr => A
# 	RangeSet(ranges={'x': [2228, 2518), 'm': (-inf, 623], 'a': (2405, 2892], 's': (911, 1624)})
# 	RangeSet(ranges={'x': [2228, 2518), 'm': [1, 623], 'a': (2405, 2892], 's': (911, 1624)})
# 	62646238480
# cd => qjl => zdd => szq => cn => nl => A
# 	RangeSet(ranges={'x': (2438, inf), 'm': (-inf, inf), 'a': (2405, inf), 's': (174, 450)})
# 	RangeSet(ranges={'x': (2438, 4000], 'm': [1, 4000], 'a': (2405, 4000], 's': (174, 450)})
# 	2740529000000
# cd => qjl => zdd => szq => cn => nl => A
# 	RangeSet(ranges={'x': (2438, inf), 'm': (-inf, inf), 'a': (2405, 3022), 's': (-inf, 174]})
# 	RangeSet(ranges={'x': (2438, 4000], 'm': [1, 4000], 'a': (2405, 3022), 's': [1, 174]})
# 	669685632000
# cd => qjl => zdd => szq => cn => nl => A
# 	RangeSet(ranges={'x': (2438, inf), 'm': (-inf, 2165], 'a': [3022, inf), 's': (-inf, 174]})
# 	RangeSet(ranges={'x': (2438, 4000], 'm': [1, 2165], 'a': [3022, 4000], 's': [1, 174]})
# 	576064178580
# cd => qjl => zdd => szq => cn => A
# 	RangeSet(ranges={'x': (-inf, 2438], 'm': (-inf, inf), 'a': (2405, inf), 's': (-inf, 193)})
# 	RangeSet(ranges={'x': [1, 2438], 'm': [1, 4000], 'a': (2405, 4000], 's': [1, 193)})
# 	2986452480000
# cd => qjl => zdd => szq => sdd => A
# 	RangeSet(ranges={'x': (1333, inf), 'm': (-inf, inf), 'a': (2405, inf), 's': (694, 911]})
# 	RangeSet(ranges={'x': (1333, 4000], 'm': [1, 4000], 'a': (2405, 4000], 's': (694, 911]})
# 	3692354820000
# cd => qjl => zdd => szq => sdd => ffv => A
# 	RangeSet(ranges={'x': (-inf, 1333], 'm': (2118, inf), 'a': (2405, inf), 's': (792, 911]})
# 	RangeSet(ranges={'x': [1, 1333], 'm': (2118, 4000], 'a': (2405, 4000], 's': (792, 911]})
# 	476164942330
# cd => qjl => zdd => szq => sdd => ffv => A
# 	RangeSet(ranges={'x': (-inf, 591), 'm': (-inf, 2118], 'a': (2405, inf), 's': (792, 911]})
# 	RangeSet(ranges={'x': [1, 591), 'm': [1, 2118], 'a': (2405, 4000], 's': (792, 911]})
# 	237184124100
# cd => qjl => zdd => szq => sdd => qc => A
# 	RangeSet(ranges={'x': (-inf, 1333], 'm': (-inf, inf), 'a': (2405, 3321], 's': (694, 792]})
# 	RangeSet(ranges={'x': [1, 1333], 'm': [1, 4000], 'a': (2405, 3321], 's': (694, 792]})
# 	478642976000
# cd => qjl => zdd => szq => lk => bj => A
# 	RangeSet(ranges={'x': (-inf, 2353], 'm': (-inf, inf), 'a': (3257, inf), 's': [450, 567]})
# 	RangeSet(ranges={'x': [1, 2353], 'm': [1, 4000], 'a': (3257, 4000], 's': [450, 567]})
# 	825187688000
# cd => qjl => zdd => szq => lk => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': (-inf, inf), 'a': (2920, 3257], 's': [450, 567]})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [1, 4000], 'a': (2920, 3257], 's': [450, 567]})
# 	636256000000
# cd => qjl => zdd => szq => lk => fv => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': (2847, inf), 'a': (2405, 2920], 's': [450, 496]})
# 	RangeSet(ranges={'x': [1, 4000], 'm': (2847, 4000], 'a': (2405, 2920], 's': [450, 496]})
# 	111633460000
# cd => qjl => klp => jzp => nrj => ml => A
# 	RangeSet(ranges={'x': (-inf, 1378), 'm': (2093, inf), 'a': (2405, inf), 's': (2051, 2137)})
# 	RangeSet(ranges={'x': [1, 1378), 'm': (2093, 4000], 'a': (2405, 4000], 's': (2051, 2137)})
# 	356011679925
# cd => qjl => klp => jzp => nrj => ml => A
# 	RangeSet(ranges={'x': (705, 1378), 'm': [723, 2093], 'a': (2405, inf), 's': (2051, 2137)})
# 	RangeSet(ranges={'x': (705, 1378), 'm': [723, 2093], 'a': (2405, 4000], 's': (2051, 2137)})
# 	124906874400
# cd => qjl => klp => jzp => nrj => ml => A
# 	RangeSet(ranges={'x': (-inf, 705], 'm': [723, 2093], 'a': (2405, inf), 's': (2051, 2137)})
# 	RangeSet(ranges={'x': [1, 705], 'm': [723, 2093], 'a': (2405, 4000], 's': (2051, 2137)})
# 	131040694125
# cd => qjl => klp => jzp => nrj => A
# 	RangeSet(ranges={'x': (-inf, 1378), 'm': (-inf, inf), 'a': (2405, 3354), 's': (1981, 2051]})
# 	RangeSet(ranges={'x': [1, 1378), 'm': [1, 4000], 'a': (2405, 3354), 's': (1981, 2051]})
# 	365510880000
# cd => qjl => klp => jzp => nrj => czr => A
# 	RangeSet(ranges={'x': [772, 1378), 'm': (-inf, 2538], 'a': [3354, inf), 's': (1981, 2051]})
# 	RangeSet(ranges={'x': [772, 1378), 'm': [1, 2538], 'a': [3354, 4000], 's': (1981, 2051]})
# 	69657288120
# cd => qjl => klp => jzp => qm => A
# 	RangeSet(ranges={'x': [1378, inf), 'm': (-inf, inf), 'a': (2405, 3400), 's': (1981, 2137)})
# 	RangeSet(ranges={'x': [1378, 4000], 'm': [1, 4000], 'a': (2405, 3400), 's': (1981, 2137)})
# 	1616502440000
# cd => qjl => klp => qnz => bz => jz => A
# 	RangeSet(ranges={'x': (1502, inf), 'm': (1947, inf), 'a': (3073, 3649), 's': [2137, 2440)})
# 	RangeSet(ranges={'x': (1502, 4000], 'm': (1947, 4000], 'a': (3073, 3649), 's': [2137, 2440)})
# 	893494444650
# cd => qjl => klp => qnz => bz => A
# 	RangeSet(ranges={'x': (1502, inf), 'm': (1947, inf), 'a': (2405, 3073], 's': (2285, 2440)})
# 	RangeSet(ranges={'x': (1502, 4000], 'm': (1947, 4000], 'a': (2405, 3073], 's': (2285, 2440)})
# 	527568147568
# cd => qjl => klp => qnz => bz => tt => A
# 	RangeSet(ranges={'x': (1502, inf), 'm': (2870, inf), 'a': (2653, 3073], 's': [2228, 2285]})
# 	RangeSet(ranges={'x': (1502, 4000], 'm': (2870, 4000], 'a': (2653, 3073], 's': [2228, 2285]})
# 	68761946400
# cd => qjl => klp => qnz => bz => tt => A
# 	RangeSet(ranges={'x': [2943, inf), 'm': (1947, 2870], 'a': (2653, 3073], 's': [2228, 2285]})
# 	RangeSet(ranges={'x': [2943, 4000], 'm': (1947, 2870], 'a': (2653, 3073], 's': [2228, 2285]})
# 	23788368240
# cd => qjl => klp => qnz => bz => sgd => A
# 	RangeSet(ranges={'x': (1502, inf), 'm': (1947, 2302), 'a': (2405, 2653], 's': [2137, 2285]})
# 	RangeSet(ranges={'x': (1502, 4000], 'm': (1947, 2302), 'a': (2405, 2653], 's': [2137, 2285]})
# 	32676357984
# cd => qjl => klp => qnz => bz => sgd => A
# 	RangeSet(ranges={'x': (1502, inf), 'm': [2302, 2799], 'a': (2405, 2653], 's': (2226, 2285]})
# 	RangeSet(ranges={'x': (1502, 4000], 'm': [2302, 2799], 'a': (2405, 2653], 's': (2226, 2285]})
# 	18202266528
# cd => qjl => klp => qnz => bz => sgd => A
# 	RangeSet(ranges={'x': (1502, inf), 'm': [2302, 2799], 'a': (2405, 2653], 's': [2137, 2226]})
# 	RangeSet(ranges={'x': (1502, 4000], 'm': [2302, 2799], 'a': (2405, 2653], 's': [2137, 2226]})
# 	27766169280
# cd => qjl => klp => qnz => jr => zvg => A
# 	RangeSet(ranges={'x': (1502, 2063), 'm': (-inf, 1947], 'a': (2405, inf), 's': (2319, 2440)})
# 	RangeSet(ranges={'x': (1502, 2063), 'm': [1, 1947], 'a': (2405, 4000], 's': (2319, 2440)})
# 	208687248000
# cd => qjl => klp => qnz => jr => zvg => A
# 	RangeSet(ranges={'x': (1801, 2063), 'm': (-inf, 1947], 'a': (2405, inf), 's': [2137, 2319]})
# 	RangeSet(ranges={'x': (1801, 2063), 'm': [1, 1947], 'a': (2405, 4000], 's': [2137, 2319]})
# 	148326324795
# cd => qjl => klp => qnz => jr => zvg => A
# 	RangeSet(ranges={'x': (1502, 1801], 'm': (-inf, 1947], 'a': (2405, inf), 's': [2137, 2319]})
# 	RangeSet(ranges={'x': (1502, 1801], 'm': [1, 1947], 'a': (2405, 4000], 's': [2137, 2319]})
# 	169921728405
# cd => qjl => klp => qnz => jr => A
# 	RangeSet(ranges={'x': [2063, 2340), 'm': (-inf, 1947], 'a': (2405, inf), 's': [2137, 2440)})
# 	RangeSet(ranges={'x': [2063, 2340), 'm': [1, 1947], 'a': (2405, 4000], 's': [2137, 2440)})
# 	260644782915
# cd => qjl => klp => qnz => jr => cl => A
# 	RangeSet(ranges={'x': [2340, 2553), 'm': (945, 1947], 'a': (2405, inf), 's': [2137, 2245]})
# 	RangeSet(ranges={'x': [2340, 2553), 'm': (945, 1947], 'a': (2405, 4000], 's': [2137, 2245]})
# 	37105177230
# cd => qjl => klp => qnz => prq => xxf => A
# 	RangeSet(ranges={'x': [2553, 3256), 'm': (1340, 1947], 'a': (2405, inf), 's': [2137, 2440)})
# 	RangeSet(ranges={'x': [2553, 3256), 'm': (1340, 1947], 'a': (2405, 4000], 's': [2137, 2440)})
# 	206227858485
# cd => qjl => klp => qnz => bx => gf => A
# 	RangeSet(ranges={'x': [3256, 3539), 'm': (928, 1947], 'a': (2405, inf), 's': [2240, 2440)})
# 	RangeSet(ranges={'x': [3256, 3539), 'm': (928, 1947], 'a': (2405, 4000], 's': [2240, 2440)})
# 	91992263000
# cd => qjl => klp => qnz => bx => gm => A
# 	RangeSet(ranges={'x': [3256, 3724), 'm': (-inf, 317), 'a': (2405, inf), 's': [2240, 2440)})
# 	RangeSet(ranges={'x': [3256, 3724), 'm': [1, 317), 'a': (2405, 4000], 's': [2240, 2440)})
# 	47176272000
# cd => qjl => klp => qnz => bx => gm => A
# 	RangeSet(ranges={'x': [3256, 3724), 'm': [317, 928], 'a': (2405, inf), 's': [2240, 2440)})
# 	RangeSet(ranges={'x': [3256, 3724), 'm': [317, 928], 'a': (2405, 4000], 's': [2240, 2440)})
# 	91366704000
# cd => qjl => klp => xj => lv => tqj => A
# 	RangeSet(ranges={'x': (-inf, 1502], 'm': (261, 649], 'a': (2405, 3333), 's': [2137, 2246)})
# 	RangeSet(ranges={'x': [1, 1502], 'm': (261, 649], 'a': (2405, 3333), 's': [2137, 2246)})
# 	58885435368
# cd => qjl => klp => xj => lv => tqj => A
# 	RangeSet(ranges={'x': (-inf, 1502], 'm': (-inf, 261], 'a': (2405, 3333), 's': [2137, 2246)})
# 	RangeSet(ranges={'x': [1, 1502], 'm': [1, 261], 'a': (2405, 3333), 's': [2137, 2246)})
# 	39611078946
# cd => qjl => klp => xj => lv => hth => A
# 	RangeSet(ranges={'x': (-inf, 263), 'm': (-inf, inf), 'a': [3333, inf), 's': [2137, 2246)})
# 	RangeSet(ranges={'x': [1, 263), 'm': [1, 4000], 'a': [3333, 4000], 's': [2137, 2246)})
# 	76306976000
# cd => qjl => klp => xj => lv => hth => A
# 	RangeSet(ranges={'x': [263, 532], 'm': (-inf, inf), 'a': [3333, inf), 's': [2137, 2246)})
# 	RangeSet(ranges={'x': [263, 532], 'm': [1, 4000], 'a': [3333, 4000], 's': [2137, 2246)})
# 	78636960000
# cd => qjl => klp => xj => hnk => cqm => A
# 	RangeSet(ranges={'x': (-inf, 1502], 'm': (-inf, 1382), 'a': (2405, 3300), 's': [2246, 2440)})
# 	RangeSet(ranges={'x': [1, 1502], 'm': [1, 1382), 'a': (2405, 3300), 's': [2246, 2440)})
# 	359751704232
# cd => qjl => klp => xj => hnk => A
# 	RangeSet(ranges={'x': [618, 1502], 'm': (2969, inf), 'a': (2405, inf), 's': [2246, 2440)})
# 	RangeSet(ranges={'x': [618, 1502], 'm': (2969, 4000], 'a': (2405, 4000], 's': [2246, 2440)})
# 	282334762050
# cd => qjl => klp => xj => hnk => ck => A
# 	RangeSet(ranges={'x': [618, 994), 'm': [1382, 2969], 'a': (2405, inf), 's': [2246, 2440)})
# 	RangeSet(ranges={'x': [618, 994), 'm': [1382, 2969], 'a': (2405, 4000], 's': [2246, 2440)})
# 	184756939840
# cd => qjl => klp => xj => hnk => ck => A
# 	RangeSet(ranges={'x': [994, 1502], 'm': [1382, 2969], 'a': (2405, inf), 's': (2364, 2440)})
# 	RangeSet(ranges={'x': [994, 1502], 'm': [1382, 2969], 'a': (2405, 4000], 's': (2364, 2440)})
# 	96691930500
# cd => qjl => klp => xj => hnk => ck => A
# 	RangeSet(ranges={'x': [994, 1502], 'm': (2064, 2969], 'a': (2405, inf), 's': [2246, 2364]})
# 	RangeSet(ranges={'x': [994, 1502], 'm': (2064, 2969], 'a': (2405, 4000], 's': [2246, 2364]})
# 	87432724225
# cd => qjl => bhv => btz => dr => qvk => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': (-inf, inf), 'a': (3068, inf), 's': (1739, 1772)})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [1, 4000], 'a': (3068, 4000], 's': (1739, 1772)})
# 	477184000000
# cd => qjl => bhv => btz => dr => gk => A
# 	RangeSet(ranges={'x': [2559, inf), 'm': [2207, inf), 'a': (3068, 3629], 's': [1624, 1739]})
# 	RangeSet(ranges={'x': [2559, 4000], 'm': [2207, 4000], 'a': (3068, 3629], 's': [1624, 1739]})
# 	168348228048
# cd => qjl => bhv => btz => hfb => xc => A
# 	RangeSet(ranges={'x': (-inf, 1738), 'm': (-inf, inf), 'a': (2668, 2881), 's': [1624, 1815)})
# 	RangeSet(ranges={'x': [1, 1738), 'm': [1, 4000], 'a': (2668, 2881), 's': [1624, 1815)})
# 	281338416000
# cd => qjl => bhv => btz => cs => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': (1405, 2408), 'a': (2405, 2668], 's': [1624, 1815)})
# 	RangeSet(ranges={'x': [1, 4000], 'm': (1405, 2408), 'a': (2405, 2668], 's': [1624, 1815)})
# 	201333864000
# cd => qjl => bhv => btz => cs => A
# 	RangeSet(ranges={'x': (2157, inf), 'm': (-inf, 1405], 'a': (2405, 2668], 's': [1624, 1815)})
# 	RangeSet(ranges={'x': (2157, 4000], 'm': [1, 1405], 'a': (2405, 2668], 's': [1624, 1815)})
# 	130074083695
# cd => qjl => bhv => btz => cs => tp => A
# 	RangeSet(ranges={'x': (-inf, 1044), 'm': (-inf, 1405], 'a': (2405, 2668], 's': [1624, 1815)})
# 	RangeSet(ranges={'x': [1, 1044), 'm': [1, 1405], 'a': (2405, 2668], 's': [1624, 1815)})
# 	73612191695
# cd => qjl => bhv => btz => cs => tp => A
# 	RangeSet(ranges={'x': [1044, 2157], 'm': (-inf, 1405], 'a': (2510, 2668], 's': [1624, 1815)})
# 	RangeSet(ranges={'x': [1044, 2157], 'm': [1, 1405], 'a': (2510, 2668], 's': [1624, 1815)})
# 	47233700260
# cd => qjl => bhv => btz => cs => tp => A
# 	RangeSet(ranges={'x': [1044, 2157], 'm': (-inf, 1405], 'a': (2405, 2510], 's': [1624, 1735)})
# 	RangeSet(ranges={'x': [1044, 2157], 'm': [1, 1405], 'a': (2405, 2510], 's': [1624, 1735)})
# 	18242056350
# cd => qjl => bhv => btz => cs => tp => A
# 	RangeSet(ranges={'x': [1044, 2157], 'm': (-inf, 1405], 'a': (2405, 2510], 's': [1735, 1815)})
# 	RangeSet(ranges={'x': [1044, 2157], 'm': [1, 1405], 'a': (2405, 2510], 's': [1735, 1815)})
# 	13147428000
# cd => qjl => bhv => btz => fgr => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': (3145, inf), 'a': (2405, 2668], 's': [1624, 1815)})
# 	RangeSet(ranges={'x': [1, 4000], 'm': (3145, 4000], 'a': (2405, 2668], 's': [1624, 1815)})
# 	171796860000
# cd => qjl => bhv => rh => md => A
# 	RangeSet(ranges={'x': (1522, inf), 'm': (-inf, inf), 'a': (2405, 2755), 's': [1815, 1981]})
# 	RangeSet(ranges={'x': (1522, 4000], 'm': [1, 4000], 'a': (2405, 2755), 's': [1815, 1981]})
# 	577701096000
# cd => qjl => bhv => rh => md => bqz => A
# 	RangeSet(ranges={'x': (1522, inf), 'm': (-inf, inf), 'a': [2755, 2865], 's': [1815, 1981]})
# 	RangeSet(ranges={'x': (1522, 4000], 'm': [1, 4000], 'a': [2755, 2865], 's': [1815, 1981]})
# 	183738744000
# cd => qjl => bhv => rh => md => A
# 	RangeSet(ranges={'x': (1522, inf), 'm': (-inf, 1812), 'a': [2974, 3302), 's': [1815, 1981]})
# 	RangeSet(ranges={'x': (1522, 4000], 'm': [1, 1812), 'a': [2974, 3302), 's': [1815, 1981]})
# 	245815954608
# cd => qjl => bhv => rh => zmb => A
# 	RangeSet(ranges={'x': (-inf, 854), 'm': (-inf, inf), 'a': (2405, 3302), 's': [1815, 1981]})
# 	RangeSet(ranges={'x': [1, 854), 'm': [1, 4000], 'a': (2405, 3302), 's': [1815, 1981]})
# 	510544384000
# cd => qjl => bhv => rh => zmb => tv => A
# 	RangeSet(ranges={'x': [1247, 1522], 'm': (2373, inf), 'a': (2405, 3302), 's': [1815, 1981]})
# 	RangeSet(ranges={'x': [1247, 1522], 'm': (2373, 4000], 'a': (2405, 3302), 's': [1815, 1981]})
# 	67192548864
# cd => qjl => bhv => xs => pxv => nt => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': (-inf, 518), 'a': [3562, 3725), 's': [1815, 1880]})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [1, 518), 'a': [3562, 3725), 's': [1815, 1880]})
# 	22247544000
# cd => qjl => bhv => xs => pxv => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': (-inf, 518), 'a': [3725, 3830), 's': [1815, 1981]})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [1, 518), 'a': [3725, 3830), 's': [1815, 1981]})
# 	36262380000
# cd => qjl => bhv => xs => pxv => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': (-inf, 518), 'a': [3830, inf), 's': [1815, 1981]})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [1, 518), 'a': [3830, 4000], 's': [1815, 1981]})
# 	59055876000
# cd => qjl => bhv => xs => rxz => ft => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': [518, 1121), 'a': (3491, 3589), 's': [1815, 1981]})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [518, 1121), 'a': (3491, 3589), 's': [1815, 1981]})
# 	39071988000
# cd => qjl => bhv => xs => rxz => ft => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': [1121, 1426), 'a': (3491, 3589), 's': (1882, 1981]})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [1121, 1426), 'a': (3491, 3589), 's': (1882, 1981]})
# 	11715660000
# cd => qjl => bhv => xs => rxz => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': [518, 1104], 'a': [3302, 3491], 's': [1815, 1879)})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [518, 1104], 'a': [3302, 3491], 's': [1815, 1879)})
# 	28551680000
# cd => qjl => bhv => xs => rxz => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': [518, 1104], 'a': [3302, 3491], 's': [1879, 1981]})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [518, 1104], 'a': [3302, 3491], 's': [1879, 1981]})
# 	45950360000
# cd => qjl => bhv => xs => dv => dt => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': [518, 1426), 'a': (3783, 3900), 's': [1907, 1981]})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [518, 1426), 'a': (3783, 3900), 's': [1907, 1981]})
# 	31598400000
# cd => qjl => bhv => xs => dv => pll => A
# 	RangeSet(ranges={'x': [2401, inf), 'm': [518, 1426), 'a': (3952, inf), 's': [1875, 1928)})
# 	RangeSet(ranges={'x': [2401, 4000], 'm': [518, 1426), 'a': (3952, 4000], 's': [1875, 1928)})
# 	3695923200
# cd => qjl => bhv => xs => dv => pll => A
# 	RangeSet(ranges={'x': [2401, inf), 'm': [518, 1426), 'a': (3979, inf), 's': [1928, 1981]})
# 	RangeSet(ranges={'x': [2401, 4000], 'm': [518, 1426), 'a': (3979, 4000], 's': [1928, 1981]})
# 	1647475200
# cd => qjl => bhv => xs => dv => A
# 	RangeSet(ranges={'x': [2401, inf), 'm': [518, 1426), 'a': [3900, 3952], 's': [1815, 1981]})
# 	RangeSet(ranges={'x': [2401, 4000], 'm': [518, 1426), 'a': [3900, 3952], 's': [1815, 1981]})
# 	12858732800
# cd => qjl => bhv => xs => gr => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': [518, 1426), 'a': [3589, 3783], 's': (1874, 1981]})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [518, 1426), 'a': [3589, 3783], 's': (1874, 1981]})
# 	75781680000
# cd => qjl => bhv => xs => gr => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': [518, 1426), 'a': [3589, 3783], 's': [1815, 1874]})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [518, 1426), 'a': [3589, 3783], 's': [1815, 1874]})
# 	42494400000
# cd => qjl => bhv => dfq => hjr => jcv => A
# 	RangeSet(ranges={'x': (3293, inf), 'm': [1426, inf), 'a': [3302, inf), 's': (1884, 1927]})
# 	RangeSet(ranges={'x': (3293, 4000], 'm': [1426, 4000], 'a': [3302, 4000], 's': (1884, 1927]})
# 	54719519925
# cd => qjl => bhv => dfq => hjr => jcv => A
# 	RangeSet(ranges={'x': [1882, 3293], 'm': [1426, inf), 'a': [3302, inf), 's': (1884, 1927]})
# 	RangeSet(ranges={'x': [1882, 3293], 'm': [1426, 4000], 'a': [3302, 4000], 's': (1884, 1927]})
# 	109284246300
# cd => qjl => bhv => dfq => bq => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': [1426, inf), 'a': (3606, inf), 's': (1846, 1884]})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [1426, 4000], 'a': (3606, 4000], 's': (1846, 1884]})
# 	154211600000
# cd => qjl => bhv => dfq => bq => cpr => A
# 	RangeSet(ranges={'x': [2287, inf), 'm': [1426, inf), 'a': (3606, 3768], 's': (1827, 1846]})
# 	RangeSet(ranges={'x': [2287, 4000], 'm': [1426, 4000], 'a': (3606, 3768], 's': (1827, 1846]})
# 	13584906900
# cd => qjl => bhv => dfq => bq => fvr => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': [1426, inf), 'a': (3606, inf), 's': [1815, 1819)})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [1426, 4000], 'a': (3606, 4000], 's': [1815, 1819)})
# 	16232800000
# cd => qjl => bhv => dfq => bq => fvr => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': [1426, inf), 'a': (3606, 3820], 's': [1819, 1827]})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [1426, 4000], 'a': (3606, 3820], 's': [1819, 1827]})
# 	19837800000
# cd => qjl => bhv => dfq => hvz => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': [1426, 2391), 'a': [3302, 3606], 's': [1815, 1848)})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [1426, 2391), 'a': [3302, 3606], 's': [1815, 1848)})
# 	38850900000
# cd => qjl => bhv => dfq => hvz => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': [1426, 2391), 'a': [3302, 3490), 's': [1848, 1884]})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [1426, 2391), 'a': [3302, 3490), 's': [1848, 1884]})
# 	26850160000
# cd => qjl => bhv => dfq => hvz => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': [1426, 2391), 'a': [3490, 3606], 's': [1848, 1870)})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [1426, 2391), 'a': [3490, 3606], 's': [1848, 1870)})
# 	9935640000
# cd => qjl => bhv => dfq => hvz => xcc => A
# 	RangeSet(ranges={'x': (2717, inf), 'm': [1426, 2391), 'a': [3490, 3606], 's': [1870, 1884]})
# 	RangeSet(ranges={'x': (2717, 4000], 'm': [1426, 2391), 'a': [3490, 3606], 's': [1870, 1884]})
# 	2172856725
# cd => qjl => bhv => dfq => hvz => xcc => A
# 	RangeSet(ranges={'x': [1386, 2717], 'm': [1426, 2391), 'a': [3490, 3606], 's': [1870, 1884]})
# 	RangeSet(ranges={'x': [1386, 2717], 'm': [1426, 2391), 'a': [3490, 3606], 's': [1870, 1884]})
# 	2255841900
# cd => qjl => bhv => dfq => fd => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': [2391, inf), 'a': [3302, 3606], 's': [1815, 1838)})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [2391, 4000], 'a': [3302, 3606], 's': [1815, 1838)})
# 	45176600000
# cd => qjl => bhv => dfq => fd => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': [2391, 3087), 'a': [3302, 3606], 's': [1838, 1884]})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [2391, 3087), 'a': [3302, 3606], 's': [1838, 1884]})
# 	39908640000
# cd => qjl => bhv => dfq => fd => jsg => A
# 	RangeSet(ranges={'x': (1393, 2596], 'm': [3087, inf), 'a': [3302, 3495], 's': [1838, 1884]})
# 	RangeSet(ranges={'x': (1393, 2596], 'm': [3087, 4000], 'a': [3302, 3495], 's': [1838, 1884]})
# 	10025623956
# cd => qjl => bhv => dfq => fd => jsg => A
# 	RangeSet(ranges={'x': (-inf, 1393], 'm': [3087, 3518], 'a': [3302, 3495], 's': [1838, 1884]})
# 	RangeSet(ranges={'x': [1, 1393], 'm': [3087, 3518], 'a': [3302, 3495], 's': [1838, 1884]})
# 	5486993568
# cd => vv => jp => hd => rt => A
# 	RangeSet(ranges={'x': (-inf, 2530), 'm': (-inf, 814), 'a': (238, 395], 's': (-inf, 1247)})
# 	RangeSet(ranges={'x': [1, 2530), 'm': [1, 814), 'a': (238, 395], 's': [1, 1247)})
# 	402213894894
# cd => vv => jp => hd => rt => vz => A
# 	RangeSet(ranges={'x': (-inf, 2530), 'm': [408, 814), 'a': (-inf, 238], 's': (-inf, 1247)})
# 	RangeSet(ranges={'x': [1, 2530), 'm': [408, 814), 'a': [1, 238], 's': [1, 1247)})
# 	304487776152
# cd => vv => jp => hd => hdr => vfl => A
# 	RangeSet(ranges={'x': (-inf, 2530), 'm': (1494, 1670), 'a': (1549, 2405], 's': (-inf, 1247)})
# 	RangeSet(ranges={'x': [1, 2530), 'm': (1494, 1670), 'a': (1549, 2405], 's': [1, 1247)})
# 	472039873200
# cd => vv => jp => hd => hdr => vfl => A
# 	RangeSet(ranges={'x': (-inf, 2530), 'm': (1494, 1670), 'a': (-inf, 1549], 's': (-inf, 1247)})
# 	RangeSet(ranges={'x': [1, 2530), 'm': (1494, 1670), 'a': [1, 1549], 's': [1, 1247)})
# 	854193649050
# cd => vv => jp => hd => hdr => A
# 	RangeSet(ranges={'x': (-inf, 2530), 'm': [1158, 1494], 'a': (-inf, 1353), 's': (-inf, 1247)})
# 	RangeSet(ranges={'x': [1, 2530), 'm': [1158, 1494], 'a': [1, 1353), 's': [1, 1247)})
# 	1435732277616
# cd => vv => jp => pmn => mxr => pz => A
# 	RangeSet(ranges={'x': (3353, inf), 'm': (-inf, 885], 'a': (-inf, 1395), 's': (-inf, 525)})
# 	RangeSet(ranges={'x': (3353, 4000], 'm': [1, 885], 'a': [1, 1395), 's': [1, 525)})
# 	418255453320
# cd => vv => jp => pmn => mxr => fp => A
# 	RangeSet(ranges={'x': (3353, inf), 'm': (-inf, 1670), 'a': (839, 2405], 's': [525, 1247)})
# 	RangeSet(ranges={'x': (3353, 4000], 'm': [1, 1670), 'a': (839, 2405], 's': [525, 1247)})
# 	1220926647636
# cd => vv => jp => pmn => mxr => fp => A
# 	RangeSet(ranges={'x': (3353, inf), 'm': (-inf, 1670), 'a': (-inf, 370), 's': [525, 1247)})
# 	RangeSet(ranges={'x': (3353, 4000], 'm': [1, 1670), 'a': [1, 370), 's': [525, 1247)})
# 	287689612374
# cd => vv => jp => pmn => mxr => fp => A
# 	RangeSet(ranges={'x': (3353, 3697], 'm': (-inf, 1670), 'a': [370, 839], 's': [525, 1247)})
# 	RangeSet(ranges={'x': (3353, 3697], 'm': [1, 1670), 'a': [370, 839], 's': [525, 1247)})
# 	194827310240
# cd => vv => jp => pmn => xn => A
# 	RangeSet(ranges={'x': [2530, 3353], 'm': (-inf, 894], 'a': (-inf, 2405], 's': [486, 1247)})
# 	RangeSet(ranges={'x': [2530, 3353], 'm': [1, 894], 'a': [1, 2405], 's': [486, 1247)})
# 	1348231494480
# cd => vv => tvs => rg => hj => nz => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': (2607, inf), 'a': (349, 654), 's': (440, 1247)})
# 	RangeSet(ranges={'x': [1, 4000], 'm': (2607, 4000], 'a': (349, 654), 's': (440, 1247)})
# 	1365273728000
# cd => vv => tvs => rg => hj => nz => A
# 	RangeSet(ranges={'x': [1677, inf), 'm': (2607, inf), 'a': (-inf, 349], 's': (440, 1247)})
# 	RangeSet(ranges={'x': [1677, 4000], 'm': (2607, 4000], 'a': [1, 349], 's': (440, 1247)})
# 	910642067608
# cd => vv => tvs => rg => hj => bv => A
# 	RangeSet(ranges={'x': (-inf, 1898), 'm': [1670, 2607], 'a': (-inf, 654), 's': [813, 1247)})
# 	RangeSet(ranges={'x': [1, 1898), 'm': [1670, 2607], 'a': [1, 654), 's': [813, 1247)})
# 	504281551172
# cd => vv => tvs => rg => hj => bv => A
# 	RangeSet(ranges={'x': [1898, inf), 'm': [1670, 2291), 'a': (-inf, 654), 's': [813, 1247)})
# 	RangeSet(ranges={'x': [1898, 4000], 'm': [1670, 2291), 'a': [1, 654), 's': [813, 1247)})
# 	370112526126
# cd => vv => tvs => rg => hj => bv => A
# 	RangeSet(ranges={'x': [1898, inf), 'm': [2291, 2607], 'a': (-inf, 654), 's': [813, 1247)})
# 	RangeSet(ranges={'x': [1898, 4000], 'm': [2291, 2607], 'a': [1, 654), 's': [813, 1247)})
# 	188930226702
# cd => vv => tvs => rg => lg => A
# 	RangeSet(ranges={'x': (-inf, 2664), 'm': [1670, inf), 'a': (434, 654), 's': (-inf, 440]})
# 	RangeSet(ranges={'x': [1, 2664), 'm': [1670, 4000], 'a': (434, 654), 's': [1, 440]})
# 	598150171080
# cd => vv => tvs => rg => lg => fqp => A
# 	RangeSet(ranges={'x': [3283, 3734], 'm': (2573, inf), 'a': (434, 654), 's': (-inf, 440]})
# 	RangeSet(ranges={'x': [3283, 3734], 'm': (2573, 4000], 'a': (434, 654), 's': [1, 440]})
# 	62152585440
# cd => vv => tvs => rg => lg => fqp => A
# 	RangeSet(ranges={'x': [3283, 3734], 'm': [1670, 2573], 'a': (434, 654), 's': (-inf, 440]})
# 	RangeSet(ranges={'x': [3283, 3734], 'm': [1670, 2573], 'a': (434, 654), 's': [1, 440]})
# 	39373466880
# cd => vv => tvs => rg => ljm => A
# 	RangeSet(ranges={'x': (-inf, 2267], 'm': [1670, inf), 'a': (-inf, 175], 's': (203, 440]})
# 	RangeSet(ranges={'x': [1, 2267], 'm': [1670, 4000], 'a': [1, 175], 's': (203, 440]})
# 	219169536075
# cd => vv => tvs => fq => vgj => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': (2037, 2741), 'a': (1316, 1470), 's': (-inf, 1247)})
# 	RangeSet(ranges={'x': [1, 4000], 'm': (2037, 2741), 'a': (1316, 1470), 's': [1, 1247)})
# 	536074056000
# cd => vv => tvs => fq => vgj => mjf => A
# 	RangeSet(ranges={'x': (2320, inf), 'm': (2037, 2741), 'a': [1194, 1316], 's': (-inf, 1247)})
# 	RangeSet(ranges={'x': (2320, 4000], 'm': (2037, 2741), 'a': [1194, 1316], 's': [1, 1247)})
# 	181003828320
# cd => vv => tvs => fq => vgj => mjf => A
# 	RangeSet(ranges={'x': (-inf, 1139), 'm': (2037, 2741), 'a': [1194, 1316], 's': (-inf, 1247)})
# 	RangeSet(ranges={'x': [1, 1139), 'm': (2037, 2741), 'a': [1194, 1316], 's': [1, 1247)})
# 	122608545612
# cd => vv => tvs => fq => kfg => qtq => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': [1670, 1874), 'a': [982, 1234), 's': (-inf, 786)})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [1670, 1874), 'a': [982, 1234), 's': [1, 786)})
# 	161421120000
# cd => vv => tvs => fq => kfg => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': [1670, 1874), 'a': [654, 1470), 's': [786, 1247)})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [1670, 1874), 'a': [654, 1470), 's': [786, 1247)})
# 	306959616000
# cd => vv => tvs => fq => dtq => fjl => A
# 	RangeSet(ranges={'x': (-inf, 1785), 'm': [1874, 1926), 'a': [654, 1470), 's': (-inf, 1247)})
# 	RangeSet(ranges={'x': [1, 1785), 'm': [1874, 1926), 'a': [654, 1470), 's': [1, 1247)})
# 	94320565248
# cd => vv => tvs => fq => dtq => fjl => A
# 	RangeSet(ranges={'x': (-inf, 1785), 'm': [1926, 1968], 'a': [654, 1470), 's': (-inf, 1247)})
# 	RangeSet(ranges={'x': [1, 1785), 'm': [1926, 1968], 'a': [654, 1470), 's': [1, 1247)})
# 	77995852032
# cd => vv => tvs => fq => dtq => qpt => A
# 	RangeSet(ranges={'x': (2909, inf), 'm': [1874, 1968], 'a': [654, 1470), 's': (-inf, 1247)})
# 	RangeSet(ranges={'x': (2909, 4000], 'm': [1874, 1968], 'a': [654, 1470), 's': [1, 1247)})
# 	105379602720
# cd => vv => tvs => fq => dtq => qpt => A
# 	RangeSet(ranges={'x': [1785, 2909], 'm': [1874, 1968], 'a': (991, 1470), 's': (-inf, 1247)})
# 	RangeSet(ranges={'x': [1785, 2909], 'm': [1874, 1968], 'a': (991, 1470), 's': [1, 1247)})
# 	63653467500
# cd => vv => tvs => qdh => dfm => A
# 	RangeSet(ranges={'x': (-inf, 1435), 'm': [2741, 3324], 'a': [654, 1470), 's': (-inf, 1247)})
# 	RangeSet(ranges={'x': [1, 1435), 'm': [2741, 3324], 'a': [654, 1470), 's': [1, 1247)})
# 	851471663616
# cd => vv => tvs => qdh => sn => gdh => A
# 	RangeSet(ranges={'x': [1435, inf), 'm': (3668, inf), 'a': [654, 1044), 's': (-inf, 1247)})
# 	RangeSet(ranges={'x': [1435, 4000], 'm': (3668, 4000], 'a': [654, 1044), 's': [1, 1247)})
# 	413978117280
# cd => vv => tvs => qdh => sn => gdh => A
# 	RangeSet(ranges={'x': [1435, inf), 'm': (3668, 3889], 'a': [1044, 1313), 's': (-inf, 1247)})
# 	RangeSet(ranges={'x': [1435, 4000], 'm': (3668, 3889], 'a': [1044, 1313), 's': [1, 1247)})
# 	190072482964
# cd => vv => tvs => qdh => sn => A
# 	RangeSet(ranges={'x': (2740, inf), 'm': (3320, 3668], 'a': [654, 1470), 's': (-inf, 1247)})
# 	RangeSet(ranges={'x': (2740, 4000], 'm': (3320, 3668], 'a': [654, 1470), 's': [1, 1247)})
# 	445818401280
# cd => vv => tvs => qdh => sn => gnx => A
# 	RangeSet(ranges={'x': [1435, 2740], 'm': (3550, 3668], 'a': [654, 1470), 's': (-inf, 624]})
# 	RangeSet(ranges={'x': [1435, 2740], 'm': (3550, 3668], 'a': [654, 1470), 's': [1, 624]})
# 	78469327872
# cd => vv => tvs => qdh => sn => gnx => A
# 	RangeSet(ranges={'x': [1435, 2740], 'm': (3320, 3550], 'a': [654, 1470), 's': (-inf, 340]})
# 	RangeSet(ranges={'x': [1435, 2740], 'm': (3320, 3550], 'a': [654, 1470), 's': [1, 340]})
# 	83337427200
# cd => vv => tvs => qdh => knb => qv => A
# 	RangeSet(ranges={'x': [1435, inf), 'm': [2741, 2950), 'a': (903, 1140], 's': (-inf, 1247)})
# 	RangeSet(ranges={'x': [1435, 4000], 'm': [2741, 2950), 'a': (903, 1140], 's': [1, 1247)})
# 	158368690788
# cd => vv => tvs => qdh => knb => qv => A
# 	RangeSet(ranges={'x': [1435, inf), 'm': [2741, 2950), 'a': [654, 755), 's': (-inf, 1247)})
# 	RangeSet(ranges={'x': [1435, 4000], 'm': [2741, 2950), 'a': [654, 755), 's': [1, 1247)})
# 	67490454724
# cd => vv => tvs => qdh => knb => qv => A
# 	RangeSet(ranges={'x': [1435, inf), 'm': [2822, 2950), 'a': [755, 903], 's': (-inf, 1247)})
# 	RangeSet(ranges={'x': [1435, 4000], 'm': [2822, 2950), 'a': [755, 903], 's': [1, 1247)})
# 	60977684992
# cd => vv => tvs => qdh => xcq => vlz => A
# 	RangeSet(ranges={'x': [1435, inf), 'm': (3184, 3320], 'a': [654, 1470), 's': [287, 584]})
# 	RangeSet(ranges={'x': [1435, 4000], 'm': (3184, 3320], 'a': [654, 1470), 's': [287, 584]})
# 	84859795968
# cd => vv => dx => st => kv => A
# 	RangeSet(ranges={'x': [1403, inf), 'm': (2033, 2704), 'a': [1470, 2405], 's': (-inf, 1247)})
# 	RangeSet(ranges={'x': [1403, 4000], 'm': (2033, 2704), 'a': [1470, 2405], 's': [1, 1247)})
# 	2030055168960
# cd => vv => dx => st => mh => jcn => A
# 	RangeSet(ranges={'x': [3136, 3486), 'm': [1670, 2033], 'a': [1470, 2405], 's': (-inf, 1247)})
# 	RangeSet(ranges={'x': [3136, 3486), 'm': [1670, 2033], 'a': [1470, 2405], 's': [1, 1247)})
# 	148581014400
# cd => vv => dx => st => mh => jcn => A
# 	RangeSet(ranges={'x': [3486, inf), 'm': [1670, 2033], 'a': [1470, 2405], 's': (-inf, 1247)})
# 	RangeSet(ranges={'x': [3486, 4000], 'm': [1670, 2033], 'a': [1470, 2405], 's': [1, 1247)})
# 	218626349760
# cd => vv => dx => bnq => qcs => xh => A
# 	RangeSet(ranges={'x': (-inf, 1726), 'm': (3409, 3719), 'a': [1470, 2405], 's': (-inf, 1247)})
# 	RangeSet(ranges={'x': [1, 1726), 'm': (3409, 3719), 'a': [1470, 2405], 's': [1, 1247)})
# 	621643604400
# cd => vv => dx => bnq => qcs => xh => A
# 	RangeSet(ranges={'x': (-inf, 825), 'm': [3719, inf), 'a': [1470, 2405], 's': (-inf, 1247)})
# 	RangeSet(ranges={'x': [1, 825), 'm': [3719, 4000], 'a': [1470, 2405], 's': [1, 1247)})
# 	271000574208
# cd => vv => dx => bnq => qcs => A
# 	RangeSet(ranges={'x': (-inf, 948), 'm': [2704, 3409], 'a': [1470, 2405], 's': (-inf, 1247)})
# 	RangeSet(ranges={'x': [1, 948), 'm': [2704, 3409], 'a': [1470, 2405], 's': [1, 1247)})
# 	779737768992
# cd => vv => dx => bnq => pg => A
# 	RangeSet(ranges={'x': (2110, 2609], 'm': [2704, inf), 'a': [1470, 2405], 's': (-inf, 1247)})
# 	RangeSet(ranges={'x': (2110, 2609], 'm': [2704, 4000], 'a': [1470, 2405], 's': [1, 1247)})
# 	754804381968
# cd => vv => dx => bnq => pg => A
# 	RangeSet(ranges={'x': [1726, 2110], 'm': [2704, inf), 'a': [1470, 2405], 's': (-inf, 1247)})
# 	RangeSet(ranges={'x': [1726, 2110], 'm': [2704, 4000], 'a': [1470, 2405], 's': [1, 1247)})
# 	582364102320
# cd => psl => nb => lq => nxh => gzq => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': (1334, 1755], 'a': [1275, 2405], 's': (1912, 2440)})
# 	RangeSet(ranges={'x': [1, 4000], 'm': (1334, 1755], 'a': [1275, 2405], 's': (1912, 2440)})
# 	1003726308000
# cd => psl => nb => lq => vmx => qsd => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': [2008, 2123), 'a': (-inf, 2405], 's': (2211, 2440)})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [2008, 2123), 'a': [1, 2405], 's': (2211, 2440)})
# 	252236400000
# cd => psl => nb => lq => vmx => qsd => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': [2008, 2123), 'a': (-inf, 2405], 's': (2062, 2211]})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [2008, 2123), 'a': [1, 2405], 's': (2062, 2211]})
# 	164838700000
# cd => psl => nb => lq => vmx => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': [2123, 2296), 'a': (-inf, 2405], 's': [2335, 2440)})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [2123, 2296), 'a': [1, 2405], 's': [2335, 2440)})
# 	174747300000
# cd => psl => nb => lq => zkg => hzz => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': [2296, 2478), 'a': [910, 1539), 's': (1912, 2440)})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [2296, 2478), 'a': [910, 1539), 's': (1912, 2440)})
# 	241319624000
# cd => psl => nb => lq => zkg => xdc => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': [2296, 2651), 'a': [1539, 1886), 's': [2011, 2149)})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [2296, 2651), 'a': [1539, 1886), 's': [2011, 2149)})
# 	67998120000
# cd => psl => nb => kjq => lvf => ghz => A
# 	RangeSet(ranges={'x': (1927, inf), 'm': (-inf, 593), 'a': (-inf, 942), 's': (1912, 2217)})
# 	RangeSet(ranges={'x': (1927, 4000], 'm': [1, 593), 'a': [1, 942), 's': (1912, 2217)})
# 	351062317824
# cd => psl => nb => kjq => lvf => ghz => A
# 	RangeSet(ranges={'x': (-inf, 1927], 'm': (-inf, 593), 'a': (-inf, 394), 's': (1912, 2217)})
# 	RangeSet(ranges={'x': [1, 1927], 'm': [1, 593), 'a': [1, 394), 's': (1912, 2217)})
# 	136291746048
# cd => psl => nb => kjq => lvf => ghz => A
# 	RangeSet(ranges={'x': (-inf, 1927], 'm': (-inf, 231), 'a': [394, 942), 's': (1912, 2217)})
# 	RangeSet(ranges={'x': [1, 1927], 'm': [1, 231), 'a': [394, 942), 's': (1912, 2217)})
# 	73835240320
# cd => psl => nb => kjq => lvf => fg => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': (-inf, 352), 'a': (-inf, 942), 's': [2217, 2314)})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [1, 352), 'a': [1, 942), 's': [2217, 2314)})
# 	128152908000
# cd => psl => nb => kjq => lvf => fg => A
# 	RangeSet(ranges={'x': (1421, inf), 'm': [139, 352), 'a': (-inf, 942), 's': [2314, 2440)})
# 	RangeSet(ranges={'x': (1421, 4000], 'm': [139, 352), 'a': [1, 942), 's': [2314, 2440)})
# 	65131505082
# cd => psl => nb => kjq => bcs => slv => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': [593, 658), 'a': (-inf, 942), 's': (1912, 2030]})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [593, 658), 'a': [1, 942), 's': (1912, 2030]})
# 	28869880000
# cd => psl => nb => kjq => bcs => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': [743, 873), 'a': (-inf, 942), 's': (1912, 2030]})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [743, 873), 'a': [1, 942), 's': (1912, 2030]})
# 	57739760000
# cd => psl => nb => kjq => djc => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': [873, 1334], 'a': (378, 942), 's': (2174, 2440)})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [873, 1334], 'a': (378, 942), 's': (2174, 2440)})
# 	275712360000
# cd => psl => nb => kjq => djc => js => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': [873, 1039), 'a': (378, 942), 's': (1912, 2174]})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [873, 1039), 'a': (378, 942), 's': (1912, 2174]})
# 	97943984000
# cd => psl => nb => kjq => djc => js => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': [1039, 1334], 'a': (378, 942), 's': (1912, 2174]})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [1039, 1334], 'a': (378, 942), 's': (1912, 2174]})
# 	174647104000
# cd => psl => nb => kjq => ns => fzj => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': [873, 1334], 'a': (216, 378], 's': (2118, 2440)})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [873, 1334], 'a': (216, 378], 's': (2118, 2440)})
# 	96099696000
# cd => psl => nb => kjq => ns => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': [873, 1334], 'a': (-inf, 216], 's': (1912, 2226)})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [873, 1334], 'a': [1, 216], 's': (1912, 2226)})
# 	124939584000
# cd => psl => nb => vcc => sl => rq => A
# 	RangeSet(ranges={'x': (-inf, 1452), 'm': (-inf, 618), 'a': [942, 2405], 's': [2141, 2216)})
# 	RangeSet(ranges={'x': [1, 1452), 'm': [1, 618), 'a': [942, 2405], 's': [2141, 2216)})
# 	98300316600
# cd => psl => nb => vcc => sl => rq => A
# 	RangeSet(ranges={'x': [1452, 2322), 'm': (-inf, 618), 'a': [942, 2405], 's': [2141, 2216)})
# 	RangeSet(ranges={'x': [1452, 2322), 'm': [1, 618), 'a': [942, 2405], 's': [2141, 2216)})
# 	58939542000
# cd => psl => nb => vcc => sl => rq => A
# 	RangeSet(ranges={'x': [2322, inf), 'm': (-inf, 618), 'a': [942, 2405], 's': [2141, 2216)})
# 	RangeSet(ranges={'x': [2322, 4000], 'm': [1, 618), 'a': [942, 2405], 's': [2141, 2216)})
# 	113746541400
# cd => psl => nb => vcc => zg => rp => A
# 	RangeSet(ranges={'x': (2269, inf), 'm': [618, 1334], 'a': [1774, 2405], 's': (1912, 2043)})
# 	RangeSet(ranges={'x': (2269, 4000], 'm': [618, 1334], 'a': [1774, 2405], 's': (1912, 2043)})
# 	101970994320
# cd => psl => nb => vcc => zg => rp => A
# 	RangeSet(ranges={'x': (2269, inf), 'm': [618, 1334], 'a': [1774, 2405], 's': [2043, 2216)})
# 	RangeSet(ranges={'x': (2269, 4000], 'm': [618, 1334], 'a': [1774, 2405], 's': [2043, 2216)})
# 	135699861672
# cd => psl => nb => vcc => rhs => A
# 	RangeSet(ranges={'x': (-inf, 2269], 'm': [618, 1334], 'a': [942, 1453), 's': (1912, 2216)})
# 	RangeSet(ranges={'x': [1, 2269], 'm': [618, 1334], 'a': [942, 1453), 's': (1912, 2216)})
# 	251893627209
# cd => psl => nb => vcc => rhs => kg => A
# 	RangeSet(ranges={'x': (1534, 2269], 'm': (933, 1334], 'a': [1453, 2405], 's': (1912, 2216)})
# 	RangeSet(ranges={'x': (1534, 2269], 'm': (933, 1334], 'a': [1453, 2405], 's': (1912, 2216)})
# 	85107383865
# cd => psl => nb => vcc => rhs => A
# 	RangeSet(ranges={'x': (-inf, 2269], 'm': [618, 933], 'a': [1453, 2405], 's': (1912, 2216)})
# 	RangeSet(ranges={'x': [1, 2269], 'm': [618, 933], 'a': [1453, 2405], 's': (1912, 2216)})
# 	207041358036
# cd => psl => nb => zd => ql => A
# 	RangeSet(ranges={'x': [1455, inf), 'm': (-inf, 1334], 'a': [942, 1856), 's': [2216, 2316)})
# 	RangeSet(ranges={'x': [1455, 4000], 'm': [1, 1334], 'a': [942, 1856), 's': [2216, 2316)})
# 	310427669600
# cd => psl => nb => zd => ql => dz => A
# 	RangeSet(ranges={'x': [2592, inf), 'm': (-inf, 1334], 'a': [942, 1109], 's': [2316, 2440)})
# 	RangeSet(ranges={'x': [2592, 4000], 'm': [1, 1334], 'a': [942, 1109], 's': [2316, 2440)})
# 	39155952192
# cd => psl => nb => zd => vfk => sd => A
# 	RangeSet(ranges={'x': [2625, inf), 'm': (-inf, 1334], 'a': [1856, 2405], 's': (2335, 2440)})
# 	RangeSet(ranges={'x': [2625, 4000], 'm': [1, 1334], 'a': [1856, 2405], 's': (2335, 2440)})
# 	104995404800
# cd => psl => mdx => cc => ph => mf => A
# 	RangeSet(ranges={'x': (-inf, 2510), 'm': (-inf, 1326), 'a': (-inf, 2405], 's': (1504, 1679)})
# 	RangeSet(ranges={'x': [1, 2510), 'm': [1, 1326), 'a': [1, 2405], 's': (1504, 1679)})
# 	1391172129750
# cd => psl => mdx => cc => ph => mf => A
# 	RangeSet(ranges={'x': (-inf, 2510), 'm': (-inf, 538), 'a': (-inf, 2405], 's': [1679, 1912]})
# 	RangeSet(ranges={'x': [1, 2510), 'm': [1, 538), 'a': [1, 2405], 's': [1679, 1912]})
# 	758238592410
# cd => psl => mdx => cc => ph => xtc => A
# 	RangeSet(ranges={'x': [2884, 3150], 'm': (624, 1326), 'a': (-inf, 2405], 's': (1504, 1912]})
# 	RangeSet(ranges={'x': [2884, 3150], 'm': (624, 1326), 'a': [1, 2405], 's': (1504, 1912]})
# 	183655747080
# cd => psl => mdx => cc => ph => fr => A
# 	RangeSet(ranges={'x': [2510, 3150], 'm': (-inf, 624], 'a': (-inf, 2405], 's': (1707, 1912]})
# 	RangeSet(ranges={'x': [2510, 3150], 'm': [1, 624], 'a': [1, 2405], 's': (1707, 1912]})
# 	197202111600
# cd => psl => mdx => cc => ph => fr => A
# 	RangeSet(ranges={'x': [2510, 3150], 'm': (-inf, 281), 'a': (-inf, 2405], 's': (1504, 1707]})
# 	RangeSet(ranges={'x': [2510, 3150], 'm': [1, 281), 'a': [1, 2405], 's': (1504, 1707]})
# 	87624828200
# cd => psl => mdx => cc => vd => zbh => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': [1326, 1984], 'a': (-inf, 1578), 's': (1714, 1912]})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [1326, 1984], 'a': [1, 1578), 's': (1714, 1912]})
# 	823080456000
# cd => psl => mdx => cc => vd => zbh => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': [1326, 1984], 'a': (-inf, 1578), 's': (1504, 1589]})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [1326, 1984], 'a': [1, 1578), 's': (1504, 1589]})
# 	353342620000
# cd => psl => mdx => cc => vd => A
# 	RangeSet(ranges={'x': (2560, inf), 'm': [1326, 2651), 'a': [1578, 2405], 's': (1504, 1912]})
# 	RangeSet(ranges={'x': (2560, 4000], 'm': [1326, 2651), 'a': [1578, 2405], 's': (1504, 1912]})
# 	644568192000
# cd => psl => mdx => cc => vd => A
# 	RangeSet(ranges={'x': (-inf, 2560], 'm': [1326, 2651), 'a': [1578, 2405], 's': [1772, 1912]})
# 	RangeSet(ranges={'x': [1, 2560], 'm': [1326, 2651), 'a': [1578, 2405], 's': [1772, 1912]})
# 	396009216000
# cd => psl => mdx => sb => lfn => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': (1679, 2015], 'a': (-inf, 2405], 's': [1247, 1504]})
# 	RangeSet(ranges={'x': [1, 4000], 'm': (1679, 2015], 'a': [1, 2405], 's': [1247, 1504]})
# 	833938560000
# cd => psl => mdx => sb => snz => A
# 	RangeSet(ranges={'x': (-inf, 1513], 'm': (-inf, 1679], 'a': (-inf, 2405], 's': (1408, 1504]})
# 	RangeSet(ranges={'x': [1, 1513], 'm': [1, 1679], 'a': [1, 2405], 's': (1408, 1504]})
# 	586510697760
# cd => psl => mdx => sb => klj => zs => A
# 	RangeSet(ranges={'x': (-inf, 1552), 'm': (595, 1679], 'a': (-inf, 956], 's': [1247, 1408]})
# 	RangeSet(ranges={'x': [1, 1552), 'm': (595, 1679], 'a': [1, 956], 's': [1247, 1408]})
# 	260383815648
# cd => psl => mdx => sb => klj => zs => A
# 	RangeSet(ranges={'x': [1552, inf), 'm': (595, 1047), 'a': (-inf, 956], 's': [1247, 1408]})
# 	RangeSet(ranges={'x': [1552, 4000], 'm': (595, 1047), 'a': [1, 956], 's': [1247, 1408]})
# 	171055969128
# cd => psl => mdx => sb => klj => zs => A
# 	RangeSet(ranges={'x': [1552, inf), 'm': [1047, 1679], 'a': (-inf, 956], 's': [1247, 1408]})
# 	RangeSet(ranges={'x': [1552, 4000], 'm': [1047, 1679], 'a': [1, 956], 's': [1247, 1408]})
# 	240085207224
# cd => psl => mdx => sb => klj => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': (-inf, 595], 'a': (1587, 2405], 's': [1247, 1408]})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [1, 595], 'a': (1587, 2405], 's': [1247, 1408]})
# 	315388080000
# cd => psl => mdx => sb => klj => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': (-inf, 595], 'a': (-inf, 1587], 's': [1247, 1408]})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [1, 595], 'a': [1, 1587], 's': [1247, 1408]})
# 	611883720000
# cd => cz => qk => slm => qgv => vlx => A
# 	RangeSet(ranges={'x': (2516, inf), 'm': (3174, inf), 'a': (1042, 2405], 's': (2107, 2440)})
# 	RangeSet(ranges={'x': (2516, 4000], 'm': (3174, 4000], 'a': (1042, 2405], 's': (2107, 2440)})
# 	554686872544
# cd => cz => qk => slm => qgv => rqd => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': (3174, 3616), 'a': (596, 827], 's': (2107, 2440)})
# 	RangeSet(ranges={'x': [1, 4000], 'm': (3174, 3616), 'a': (596, 827], 's': (2107, 2440)})
# 	135284688000
# cd => cz => qk => slm => pbp => hxm => A
# 	RangeSet(ranges={'x': (1425, inf), 'm': (3174, inf), 'a': (1398, 2012), 's': (1882, 2107]})
# 	RangeSet(ranges={'x': (1425, 4000], 'm': (3174, 4000], 'a': (1398, 2012), 's': (1882, 2107]})
# 	293359578750
# cd => cz => qk => slm => pbp => xt => A
# 	RangeSet(ranges={'x': (1425, inf), 'm': (3516, inf), 'a': (588, 967], 's': (1882, 2107]})
# 	RangeSet(ranges={'x': (1425, 4000], 'm': (3516, 4000], 'a': (588, 967], 's': (1882, 2107]})
# 	106278232500
# cd => cz => qk => slm => pbp => xt => A
# 	RangeSet(ranges={'x': (1425, inf), 'm': (3174, 3516], 'a': (588, 776], 's': (1882, 2107]})
# 	RangeSet(ranges={'x': (1425, 4000], 'm': (3174, 3516], 'a': (588, 776], 's': (1882, 2107]})
# 	37251495000
# cd => cz => qk => slm => nr => ls => A
# 	RangeSet(ranges={'x': (-inf, 645), 'm': (3174, inf), 'a': [1406, 2023], 's': (1965, 2107]})
# 	RangeSet(ranges={'x': [1, 645), 'm': (3174, 4000], 'a': [1406, 2023], 's': (1965, 2107]})
# 	46681277664
# cd => cz => qk => slm => nr => kmj => A
# 	RangeSet(ranges={'x': (-inf, 1425], 'm': (3174, inf), 'a': [1804, 2405], 's': [1935, 1965]})
# 	RangeSet(ranges={'x': [1, 1425], 'm': (3174, 4000], 'a': [1804, 2405], 's': [1935, 1965]})
# 	21966107100
# cd => cz => qk => jqm => xf => A
# 	RangeSet(ranges={'x': (-inf, 2410), 'm': (2948, 3098), 'a': (-inf, 2405], 's': (1882, 2440)})
# 	RangeSet(ranges={'x': [1, 2410), 'm': (2948, 3098), 'a': [1, 2405], 's': (1882, 2440)})
# 	480831979485
# cd => cz => qk => jqm => xf => cr => A
# 	RangeSet(ranges={'x': (-inf, 927), 'm': [3098, 3114], 'a': (-inf, 2405], 's': (1882, 2440)})
# 	RangeSet(ranges={'x': [1, 927), 'm': [3098, 3114], 'a': [1, 2405], 's': (1882, 2440)})
# 	21087747070
# cd => cz => qk => jqm => xf => rn => A
# 	RangeSet(ranges={'x': (-inf, 1428], 'm': [3158, 3174], 'a': (-inf, 995), 's': (1882, 2440)})
# 	RangeSet(ranges={'x': [1, 1428], 'm': [3158, 3174], 'a': [1, 995), 's': (1882, 2440)})
# 	13440601608
# cd => cz => qk => jqm => xf => vj => A
# 	RangeSet(ranges={'x': (-inf, 2410), 'm': [3128, 3174], 'a': [995, 2405], 's': (2138, 2440)})
# 	RangeSet(ranges={'x': [1, 2410), 'm': [3128, 3174], 'a': [995, 2405], 's': (2138, 2440)})
# 	48087053553
# cd => cz => qk => jqm => xf => vj => A
# 	RangeSet(ranges={'x': (-inf, 2410), 'm': (3156, 3174], 'a': [995, 2405], 's': (1882, 2138]})
# 	RangeSet(ranges={'x': [1, 2410), 'm': (3156, 3174], 'a': [995, 2405], 's': (1882, 2138]})
# 	15663048192
# cd => cz => qk => jqm => zm => txs => A
# 	RangeSet(ranges={'x': (3223, 3387], 'm': (3048, 3174], 'a': (-inf, 2405], 's': (1882, 2440)})
# 	RangeSet(ranges={'x': (3223, 3387], 'm': (3048, 3174], 'a': [1, 2405], 's': (1882, 2440)})
# 	27681184440
# cd => cz => qk => jqm => zm => txs => A
# 	RangeSet(ranges={'x': (3061, 3223], 'm': (3048, 3174], 'a': (-inf, 2405], 's': (1882, 2440)})
# 	RangeSet(ranges={'x': (3061, 3223], 'm': (3048, 3174], 'a': [1, 2405], 's': (1882, 2440)})
# 	27343609020
# cd => cz => qk => jqm => zbl => A
# 	RangeSet(ranges={'x': [2410, 3369), 'm': (2948, 3048], 'a': (-inf, 2405], 's': (1882, 2440)})
# 	RangeSet(ranges={'x': [2410, 3369), 'm': (2948, 3048], 'a': [1, 2405], 's': (1882, 2440)})
# 	128466201500
# cd => cz => qk => jqm => zbl => A
# 	RangeSet(ranges={'x': [3369, inf), 'm': (2948, 3048], 'a': (-inf, 1301), 's': (1882, 2440)})
# 	RangeSet(ranges={'x': [3369, 4000], 'm': (2948, 3048], 'a': [1, 1301), 's': (1882, 2440)})
# 	45763120000
# cd => cz => qk => jqm => zbl => A
# 	RangeSet(ranges={'x': [3369, inf), 'm': (2948, 3048], 'a': [1301, 2405], 's': (1882, 2440)})
# 	RangeSet(ranges={'x': [3369, 4000], 'm': (2948, 3048], 'a': [1301, 2405], 's': (1882, 2440)})
# 	38898652000
# cd => cz => qk => gz => tvn => A
# 	RangeSet(ranges={'x': (-inf, 1573), 'm': [2651, 2948], 'a': (-inf, 1575), 's': (1882, 2440)})
# 	RangeSet(ranges={'x': [1, 1573), 'm': [2651, 2948], 'a': [1, 1575), 's': (1882, 2440)})
# 	410703807408
# cd => cz => qk => gz => tvn => ct => A
# 	RangeSet(ranges={'x': [1573, 2963), 'm': [2651, 2948], 'a': (-inf, 1575), 's': (1882, 2440)})
# 	RangeSet(ranges={'x': [1573, 2963), 'm': [2651, 2948], 'a': [1, 1575), 's': (1882, 2440)})
# 	363154129960
# cd => cz => qk => gz => tvn => ct => A
# 	RangeSet(ranges={'x': (3312, inf), 'm': [2651, 2948], 'a': (-inf, 1575), 's': [2119, 2440)})
# 	RangeSet(ranges={'x': (3312, 4000], 'm': [2651, 2948], 'a': [1, 1575), 's': [2119, 2440)})
# 	103589196096
# cd => cz => qk => gz => tvn => ct => A
# ...
# 	225491702765
# tgz => kpt => clt => kbk => rkz => bxk => A
# 	RangeSet(ranges={'x': (1019, 1683], 'm': [3826, 3892], 'a': (1486, 1823], 's': [2440, inf)})
# 	RangeSet(ranges={'x': (1019, 1683], 'm': [3826, 3892], 'a': (1486, 1823], 's': [2440, 4000]})
# 	23403223816
# tgz => kpt => clt => kbk => rkz => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': [3808, 3892], 'a': (1388, 1486], 's': [2440, inf)})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [3808, 3892], 'a': (1388, 1486], 's': [2440, 4000]})
# 	52012520000
# tgz => kpt => clt => kbk => rkz => zkt => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': [3860, 3892], 'a': [1245, 1388], 's': [2440, 3133]})
# 	RangeSet(ranges={'x': [1, 4000], 'm': [3860, 3892], 'a': [1245, 1388], 's': [2440, 3133]})
# 	13191552000
# tgz => kpt => clt => vgh => zmk => vkb => A
# 	RangeSet(ranges={'x': (-inf, inf), 'm': (3609, 3657], 'a': (-inf, 1604), 's': [2440, inf)})
# 	RangeSet(ranges={'x': [1, 4000], 'm': (3609, 3657], 'a': [1, 1604), 's': [2440, 4000]})
# 	480438336000
# tgz => kpt => clt => vgh => ng => pjq => A
# 	RangeSet(ranges={'x': (2384, inf), 'm': [3158, 3273), 'a': (-inf, 2498], 's': [2440, inf)})
# 	RangeSet(ranges={'x': (2384, 4000], 'm': [3158, 3273), 'a': [1, 2498], 's': [2440, 4000]})
# 	724660407520
# tgz => kpt => clt => vgh => ng => pjq => A
# 	RangeSet(ranges={'x': (2384, inf), 'm': [3273, 3372), 'a': (-inf, 945), 's': [2440, inf)})
# 	RangeSet(ranges={'x': (2384, 4000], 'm': [3273, 3372), 'a': [1, 945), 's': [2440, 4000]})
# 	235749862656
# tgz => kpt => clt => vgh => ng => pjq => A
# 	RangeSet(ranges={'x': (2384, inf), 'm': [3273, 3372), 'a': [945, 2498], 's': [2440, inf)})
# 	RangeSet(ranges={'x': (2384, 4000], 'm': [3273, 3372), 'a': [945, 2498], 's': [2440, 4000]})
# 	388088227296
# tgz => kpt => clt => vgh => pt => A
# 	RangeSet(ranges={'x': (-inf, 2384], 'm': [3158, 3354], 'a': (-inf, 2498], 's': [2440, 3473)})
# 	RangeSet(ranges={'x': [1, 2384], 'm': [3158, 3354], 'a': [1, 2498], 's': [2440, 3473)})
# 	1211895667232
# tgz => dpm => dvz => kgq => bqq => A
# 	RangeSet(ranges={'x': (-inf, 2029), 'm': (1954, 2273), 'a': (-inf, 994), 's': [2440, inf)})
# 	RangeSet(ranges={'x': [1, 2029), 'm': (1954, 2273), 'a': [1, 994), 's': [2440, 4000]})
# 	999648277992
# tgz => dpm => dvz => kgq => bqq => vrm => A
# 	RangeSet(ranges={'x': (1345, 2029), 'm': (1954, 2065), 'a': [994, 1620], 's': [2440, inf)})
# 	RangeSet(ranges={'x': (1345, 2029), 'm': (1954, 2065), 'a': [994, 1620], 's': [2440, 4000]})
# 	73533262110
# tgz => dpm => dvz => kgq => bqq => vrm => A
# 	RangeSet(ranges={'x': (-inf, 1345], 'm': (1954, 2065), 'a': [994, 1620], 's': (3219, inf)})
# 	RangeSet(ranges={'x': [1, 1345], 'm': (1954, 2065), 'a': [994, 1620], 's': (3219, 4000]})
# 	72449191650
# tgz => dpm => dvz => kgq => bqq => vrm => A
# 	RangeSet(ranges={'x': (-inf, 1345], 'm': (1954, 2065), 'a': [994, 1620], 's': [2440, 3219]})
# 	RangeSet(ranges={'x': [1, 1345], 'm': (1954, 2065), 'a': [994, 1620], 's': [2440, 3219]})
# 	72356427000
# tgz => dpm => dvz => kgq => bqq => zqt => A
# 	RangeSet(ranges={'x': (-inf, 2029), 'm': [2065, 2273), 'a': [1992, 2498], 's': (3757, inf)})
# 	RangeSet(ranges={'x': [1, 2029), 'm': [2065, 2273), 'a': [1992, 2498], 's': (3757, 4000]})
# 	51969138624
# tgz => dpm => dvz => kgq => mmf => A
# 	RangeSet(ranges={'x': (-inf, 1349], 'm': (2512, 2606], 'a': (-inf, 2498], 's': [2440, inf)})
# 	RangeSet(ranges={'x': [1, 1349], 'm': (2512, 2606], 'a': [1, 2498], 's': [2440, 4000]})
# 	494464526668
# tgz => dpm => dvz => kgq => zxp => mnb => A
# 	RangeSet(ranges={'x': (1209, 2029), 'm': (2328, 2432], 'a': (-inf, 2498], 's': (3057, inf)})
# 	RangeSet(ranges={'x': (1209, 2029), 'm': (2328, 2432], 'a': [1, 2498], 's': (3057, 4000]})
# 	200641778064
# tgz => dpm => dvz => kgq => zxp => mnb => A
# 	RangeSet(ranges={'x': (1209, 2029), 'm': [2273, 2328], 'a': (-inf, 2498], 's': (3057, 3622)})
# 	RangeSet(ranges={'x': (1209, 2029), 'm': [2273, 2328], 'a': [1, 2498], 's': (3057, 3622)})
# 	64616505408
# tgz => dpm => dvz => kgq => zxp => mnb => A
# 	RangeSet(ranges={'x': (1209, 2029), 'm': [2273, 2328], 'a': (-inf, 1275), 's': [3622, inf)})
# 	RangeSet(ranges={'x': (1209, 2029), 'm': [2273, 2328], 'a': [1, 1275), 's': [3622, 4000]})
# 	22145248944
# tgz => dpm => dvz => kgq => zxp => mnb => A
# 	RangeSet(ranges={'x': (1209, 2029), 'm': [2273, 2328], 'a': [1275, 2498], 's': [3622, inf)})
# 	RangeSet(ranges={'x': (1209, 2029), 'm': [2273, 2328], 'a': [1275, 2498], 's': [3622, 4000]})
# 	21276126144
# tgz => dpm => dvz => kgq => zxp => A
# 	RangeSet(ranges={'x': (1209, 2029), 'm': [2273, 2432], 'a': (-inf, 2498], 's': [2440, 3057]})
# 	RangeSet(ranges={'x': (1209, 2029), 'm': [2273, 2432], 'a': [1, 2498], 's': [2440, 3057]})
# 	202294834560
# tgz => dpm => dvz => kgq => dzs => tbs => A
# 	RangeSet(ranges={'x': (-inf, 1209], 'm': [2273, 2432], 'a': (927, 1516), 's': [2440, inf)})
# 	RangeSet(ranges={'x': [1, 1209], 'm': [2273, 2432], 'a': (927, 1516), 's': [2440, 4000]})
# 	177552385920
# tgz => dpm => dvz => kgq => dzs => zcr => A
# 	RangeSet(ranges={'x': (-inf, 1209], 'm': [2273, 2379), 'a': [1516, 2498], 's': [2440, 3421]})
# 	RangeSet(ranges={'x': [1, 1209], 'm': [2273, 2379), 'a': [1516, 2498], 's': [2440, 3421]})
# 	123707825124
# tgz => dpm => dvz => kgq => dzs => A
# 	RangeSet(ranges={'x': (802, 1209], 'm': [2379, 2432], 'a': [1516, 2498], 's': [2440, inf)})
# 	RangeSet(ranges={'x': (802, 1209], 'm': [2379, 2432], 'a': [1516, 2498], 's': [2440, 4000]})
# 	33724427814
# tgz => dpm => dvz => kgq => dzs => lvn => A
# 	RangeSet(ranges={'x': (-inf, 802], 'm': [2379, 2432], 'a': [1516, 1975), 's': [2440, inf)})
# 	RangeSet(ranges={'x': [1, 802], 'm': [2379, 2432], 'a': [1516, 1975), 's': [2440, 4000]})
# 	31030138692
# tgz => dpm => dvz => kgq => dzs => lvn => A
# 	RangeSet(ranges={'x': (-inf, 802], 'm': [2379, 2432], 'a': [1975, 2498], 's': [2440, inf)})
# 	RangeSet(ranges={'x': [1, 802], 'm': [2379, 2432], 'a': [1975, 2498], 's': [2440, 4000]})
# 	35424384912
# tgz => dpm => dvz => hpb => cf => A
# 	RangeSet(ranges={'x': (-inf, 1249), 'm': [1744, 1954], 'a': (-inf, 2498], 's': (3313, inf)})
# 	RangeSet(ranges={'x': [1, 1249), 'm': [1744, 1954], 'a': [1, 2498], 's': (3313, 4000]})
# 	451904027328
# tgz => dpm => dvz => hpb => cf => A
# 	RangeSet(ranges={'x': (700, 1249), 'm': [1744, 1954], 'a': (-inf, 2498], 's': [2440, 3313]})
# 	RangeSet(ranges={'x': (700, 1249), 'm': [1744, 1954], 'a': [1, 2498], 's': [2440, 3313]})
# 	252445062256
# tgz => dpm => dvz => hpb => cf => A
# 	RangeSet(ranges={'x': (-inf, 700], 'm': (1872, 1954], 'a': (-inf, 2498], 's': [2440, 3313]})
# 	RangeSet(ranges={'x': [1, 700], 'm': (1872, 1954], 'a': [1, 2498], 's': [2440, 3313]})
# 	125318664800
# tgz => dpm => dvz => hpb => vkm => fb => A
# 	RangeSet(ranges={'x': (1576, 2029), 'm': [1744, 1954], 'a': (-inf, 944), 's': [2440, inf)})
# 	RangeSet(ranges={'x': (1576, 2029), 'm': [1744, 1954], 'a': [1, 944), 's': [2440, 4000]})
# 	140389777556
# tgz => dpm => dvz => hpb => vkm => cdz => A
# 	RangeSet(ranges={'x': [1249, 1644], 'm': [1744, 1862], 'a': [944, 2498], 's': [2440, inf)})
# 	RangeSet(ranges={'x': [1249, 1644], 'm': [1744, 1862], 'a': [944, 2498], 's': [2440, 4000]})
# 	114386677020
# tgz => dpm => tkb => vmr => jqd => cjt => A
# 	RangeSet(ranges={'x': [2029, 2830), 'm': [1536, 2606], 'a': (778, 1063), 's': [3222, inf)})
# 	RangeSet(ranges={'x': [2029, 2830), 'm': [1536, 2606], 'a': (778, 1063), 's': [3222, 4000]})
# 	189791948556
# tgz => dpm => tkb => vmr => jqd => jtn => A
# 	RangeSet(ranges={'x': [2830, inf), 'm': [1536, 2606], 'a': (570, 1063), 's': [2440, 3102)})
# 	RangeSet(ranges={'x': [2830, 4000], 'm': [1536, 2606], 'a': (570, 1063), 's': [2440, 3102)})
# 	408478740264
# tgz => dpm => tkb => vmr => jqd => jtn => A
# 	RangeSet(ranges={'x': [2830, inf), 'm': [2129, 2606], 'a': (570, 1063), 's': (3609, inf)})
# 	RangeSet(ranges={'x': [2830, 4000], 'm': [2129, 2606], 'a': (570, 1063), 's': (3609, 4000]})
# 	107677918536
# tgz => dpm => tkb => vmr => qvh => crs => A
# 	RangeSet(ranges={'x': [2029, 3002), 'm': (2081, 2606], 'a': [302, 570], 's': [2440, inf)})
# 	RangeSet(ranges={'x': [2029, 3002), 'm': (2081, 2606], 'a': [302, 570], 's': [2440, 4000]})
# 	214500014925
# tgz => dpm => tkb => vmr => qvh => A
# 	RangeSet(ranges={'x': [3002, inf), 'm': (2081, 2331), 'a': (-inf, 570], 's': [2440, inf)})
# 	RangeSet(ranges={'x': [3002, 4000], 'm': (2081, 2331), 'a': [1, 570], 's': [2440, 4000]})
# 	221331177270
# tgz => dpm => tkb => vmr => qvh => dh => A
# 	RangeSet(ranges={'x': [3002, inf), 'm': (2532, 2606], 'a': (-inf, 570], 's': [2440, 3294)})
# 	RangeSet(ranges={'x': [3002, 4000], 'm': (2532, 2606], 'a': [1, 570], 's': [2440, 3294)})
# 	35985698280
# tgz => dpm => tkb => vmr => qvh => dh => A
# 	RangeSet(ranges={'x': [3002, inf), 'm': [2492, 2532], 'a': (-inf, 570], 's': [2440, 3294)})
# 	RangeSet(ranges={'x': [3002, 4000], 'm': [2492, 2532], 'a': [1, 570], 's': [2440, 3294)})
# 	19938022020
# tgz => dpm => tkb => vmr => qbz => kkb => A
# 	RangeSet(ranges={'x': [2029, inf), 'm': (1814, 1913), 'a': (-inf, 570], 's': (3372, inf)})
# 	RangeSet(ranges={'x': [2029, 4000], 'm': (1814, 1913), 'a': [1, 570], 's': (3372, 4000]})
# 	69177917760
# tgz => dpm => tkb => vmr => qbz => kkb => A
# 	RangeSet(ranges={'x': [2029, inf), 'm': (1814, 1913), 'a': (295, 570], 's': [2440, 3372]})
# 	RangeSet(ranges={'x': [2029, 4000], 'm': (1814, 1913), 'a': (295, 570], 's': [2440, 3372]})
# 	49584658200
# tgz => dpm => tkb => vmr => qbz => gzd => A
# 	RangeSet(ranges={'x': [2884, inf), 'm': [2018, 2048], 'a': [286, 570], 's': [2440, inf)})
# 	RangeSet(ranges={'x': [2884, 4000], 'm': [2018, 2048], 'a': [286, 570], 's': [2440, 4000]})
# 	15405032895
# tgz => dpm => tkb => vmr => dkx => nx => A
# 	RangeSet(ranges={'x': [2537, 2834], 'm': [1536, 1814], 'a': (-inf, 570], 's': [2440, 3053)})
# 	RangeSet(ranges={'x': [2537, 2834], 'm': [1536, 1814], 'a': [1, 570], 's': [2440, 3053)})
# 	29050646220
# tgz => dpm => tkb => vmr => dkx => nx => A
# 	RangeSet(ranges={'x': (2661, 2834], 'm': [1536, 1814], 'a': (-inf, 570], 's': [3053, inf)})
# 	RangeSet(ranges={'x': (2661, 2834], 'm': [1536, 1814], 'a': [1, 570], 's': [3053, 4000]})
# 	26081556120
# tgz => dpm => tkb => vmr => dkx => nx => A
# 	RangeSet(ranges={'x': [2537, 2661], 'm': [1536, 1814], 'a': (-inf, 570], 's': [3053, 3652)})
# 	RangeSet(ranges={'x': [2537, 2661], 'm': [1536, 1814], 'a': [1, 570], 's': [3053, 3652)})
# 	11907371250
# tgz => dpm => tkb => vmr => dkx => nx => A
# 	RangeSet(ranges={'x': [2537, 2661], 'm': [1536, 1814], 'a': (-inf, 570], 's': [3652, inf)})
# 	RangeSet(ranges={'x': [2537, 2661], 'm': [1536, 1814], 'a': [1, 570], 's': [3652, 4000]})
# 	6937683750
# tgz => dpm => tkb => zlg => xbz => lkc => A
# 	RangeSet(ranges={'x': [2029, 3190), 'm': [1536, 2606], 'a': (1959, 2254), 's': [2440, 3247]})
# 	RangeSet(ranges={'x': [2029, 3190), 'm': [1536, 2606], 'a': (1959, 2254), 's': [2440, 3247]})
# 	295379520912
# tgz => dpm => tkb => zlg => xqr => A
# 	RangeSet(ranges={'x': [2029, inf), 'm': (2286, 2606], 'a': [2254, 2498], 's': [2440, inf)})
# 	RangeSet(ranges={'x': [2029, 4000], 'm': (2286, 2606], 'a': [2254, 2498], 's': [2440, 4000]})
# 	241338092800
# tgz => dpm => tkb => zlg => xqr => tf => A
# 	RangeSet(ranges={'x': [2029, inf), 'm': (1915, 2132), 'a': [2254, 2390), 's': [2440, inf)})
# 	RangeSet(ranges={'x': [2029, 4000], 'm': (1915, 2132), 'a': [2254, 2390), 's': [2440, 4000]})
# 	90427905792
# tgz => dpm => tkb => zlg => xqr => tf => A
# 	RangeSet(ranges={'x': [2029, inf), 'm': (2187, 2286], 'a': [2254, 2390), 's': [2440, inf)})
# 	RangeSet(ranges={'x': [2029, 4000], 'm': (2187, 2286], 'a': [2254, 2390), 's': [2440, 4000]})
# 	41446123488
# tgz => dpm => tkb => zlg => xqr => tf => A
# 	RangeSet(ranges={'x': [2029, inf), 'm': [2132, 2187], 'a': [2254, 2390), 's': [2440, inf)})
# 	RangeSet(ranges={'x': [2029, 4000], 'm': [2132, 2187], 'a': [2254, 2390), 's': [2440, 4000]})
# 	23444271872
# tgz => dpm => tkb => zlg => xqr => fkk => A
# 	RangeSet(ranges={'x': [2029, 3254], 'm': (1915, 2286], 'a': [2390, 2498], 's': [2440, 3440)})
# 	RangeSet(ranges={'x': [2029, 3254], 'm': (1915, 2286], 'a': [2390, 2498], 's': [2440, 3440)})
# 	49578214000
# tgz => dpm => tkb => zlg => qhg => vgc => A
# 	RangeSet(ranges={'x': [2029, inf), 'm': [1536, 1782), 'a': [2254, 2498], 's': (3045, inf)})
# 	RangeSet(ranges={'x': [2029, 4000], 'm': [1536, 1782), 'a': [2254, 2498], 's': (3045, 4000]})
# 	113504080200
# tgz => dpm => tkb => zlg => qhg => vgc => A
# 	RangeSet(ranges={'x': [2029, inf), 'm': [1536, 1782), 'a': [2254, 2498], 's': [2440, 2796]})
# 	RangeSet(ranges={'x': [2029, 4000], 'm': [1536, 1782), 'a': [2254, 2498], 's': [2440, 2796]})
# 	42430321080
# tgz => dpm => tkb => zlg => qhg => A
# 	RangeSet(ranges={'x': [2029, inf), 'm': [1782, 1915], 'a': [2254, 2401), 's': [2440, inf)})
# 	RangeSet(ranges={'x': [2029, 4000], 'm': [1782, 1915], 'a': [2254, 2401), 's': [2440, 4000]})
# 	60636195816
# tgz => dpm => tkb => zlg => qhg => rr => A
# 	RangeSet(ranges={'x': [2029, 3035), 'm': [1782, 1915], 'a': [2401, 2498], 's': [2440, inf)})
# 	RangeSet(ranges={'x': [2029, 3035), 'm': [1782, 1915], 'a': [2401, 2498], 's': [2440, 4000]})
# 	20622046312
# tgz => dpm => tkb => zlg => qhg => rr => A
# 	RangeSet(ranges={'x': [3035, inf), 'm': [1782, 1915], 'a': [2401, 2498], 's': [2440, 3096)})
# 	RangeSet(ranges={'x': [3035, 4000], 'm': [1782, 1915], 'a': [2401, 2498], 's': [2440, 3096)})
# 	8321695872
# tgz => dpm => tkb => zlg => qhg => rr => A
# 	RangeSet(ranges={'x': [3035, inf), 'm': [1782, 1915], 'a': [2451, 2498], 's': [3096, inf)})
# 	RangeSet(ranges={'x': [3035, 4000], 'm': [1782, 1915], 'a': [2451, 2498], 's': [3096, 4000]})
# 	5623047360
# tgz => dpm => tkb => ctf => dhz => dnd => A
# 	RangeSet(ranges={'x': [2029, inf), 'm': (2182, 2327), 'a': [1063, 1631), 's': [3340, inf)})
# 	RangeSet(ranges={'x': [2029, 4000], 'm': (2182, 2327), 'a': [1063, 1631), 's': [3340, 4000]})
# 	106615217664
# tgz => dpm => tkb => ctf => dhz => A
# 	RangeSet(ranges={'x': [3029, inf), 'm': [2461, 2606], 'a': [1063, 1959], 's': [2440, inf)})
# 	RangeSet(ranges={'x': [3029, 4000], 'm': [2461, 2606], 'a': [1063, 1959], 's': [2440, 4000]})
# 	198707594904
# tgz => dpm => tkb => ctf => cj => kjg => A
# 	RangeSet(ranges={'x': [2029, 2443], 'm': [1536, 2182], 'a': [1063, 1959], 's': (3563, inf)})
# 	RangeSet(ranges={'x': [2029, 2443], 'm': [1536, 2182], 'a': [1063, 1959], 's': (3563, 4000]})
# 	105251006445
# tgz => dpm => tkb => ctf => cj => kjg => A
# 	RangeSet(ranges={'x': [2029, 2443], 'm': [1536, 2182], 'a': [1063, 1959], 's': (3326, 3563]})
# 	RangeSet(ranges={'x': [2029, 2443], 'm': [1536, 2182], 'a': [1063, 1959], 's': (3326, 3563]})
# 	57081209445
# tgz => dpm => tkb => ctf => cj => A
# 	RangeSet(ranges={'x': [2805, 3336), 'm': [1536, 2182], 'a': [1063, 1959], 's': (3326, inf)})
# 	RangeSet(ranges={'x': [2805, 3336), 'm': [1536, 2182], 'a': [1063, 1959], 's': (3326, 4000]})
# 	207707003946
# tgz => dpm => tkb => ctf => mv => A
# 	RangeSet(ranges={'x': [2029, inf), 'm': [1536, 1685), 'a': [1063, 1959], 's': [2440, 3326]})
# 	RangeSet(ranges={'x': [2029, 4000], 'm': [1536, 1685), 'a': [1063, 1959], 's': [2440, 3326]})
# 	233781016092
# tgz => dpm => tkb => ctf => mv => A
# 	RangeSet(ranges={'x': [2029, inf), 'm': [1685, 1769), 'a': [1063, 1959], 's': [2440, 2921)})
# 	RangeSet(ranges={'x': [2029, 4000], 'm': [1685, 1769), 'a': [1063, 1959], 's': [2440, 2921)})
# 	71469989136
# tgz => dpm => tkb => ctf => mv => nrm => A
# 	RangeSet(ranges={'x': [2693, 3329], 'm': [1685, 1769), 'a': [1063, 1508), 's': [2921, 3099)})
# 	RangeSet(ranges={'x': [2693, 3329], 'm': [1685, 1769), 'a': [1063, 1508), 's': [2921, 3099)})
# 	4238368680
# tgz => dpm => tkb => ctf => mv => A
# 	RangeSet(ranges={'x': [2029, inf), 'm': [1685, 1769), 'a': [1063, 1959], 's': [3099, 3326]})
# 	RangeSet(ranges={'x': [2029, 4000], 'm': [1685, 1769), 'a': [1063, 1959], 's': [3099, 3326]})
# 	33877666368
# tgz => dpm => tkb => ctf => xxb => dtt => A
# 	RangeSet(ranges={'x': [2029, 2469), 'm': [1769, 2182], 'a': [1063, 1959], 's': [2440, 2993]})
# 	RangeSet(ranges={'x': [2029, 2469), 'm': [1769, 2182], 'a': [1063, 1959], 's': [2440, 2993]})
# 	90522226080
# tgz => dpm => tkb => ctf => xxb => dtt => A
# 	RangeSet(ranges={'x': (2652, 2787], 'm': [1769, 2182], 'a': [1063, 1959], 's': [2440, 2993]})
# 	RangeSet(ranges={'x': (2652, 2787], 'm': [1769, 2182], 'a': [1063, 1959], 's': [2440, 2993]})
# 	27773864820

# %%
total
# Out:
# 122112157518711
